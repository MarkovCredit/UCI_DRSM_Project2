# %%
import pymongo
import pandas as pd
import json

# %%
# Create connection variable
conn = 'mongodb://localhost:27017'
# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)
# Connect to a database. Will create one if not already available.
db = client.jobs_db

# %%
State = 'CA'

# %%
jobs_data = list(db.jobs_glassdoor.find())
df = pd.DataFrame(jobs_data)
df = df.drop(['_id'], axis=1)
df = df.drop_duplicates(keep = 'first')
# df = df.loc[df["Avg Salary"] > 0 ]
df = df.loc[df["State"] == State]
df
# Out:
#      Avg Salary           City                                 Company  \
# 6          65.0     Sacramento                         UC Davis Health
# 11        107.0      Sunnyvale                       Walmart eCommerce
# 13        117.0   Agoura Hills                                PennyMac
# 15          NaN         Newark                        Marlette Funding
# 17        110.0  San Francisco                        Healthline Media
# 18         58.0        Rocklin               American Pacific Mortgage
# 28        141.5       San Jose                      Affinity Solutions
# 30        117.0   Agoura Hills                                PennyMac
# 36        111.5  San Francisco                                   Zynga
# 46         64.5     Loma Linda    Loma Linda University Medical Center
# 51         78.5  San Francisco                                Everlane
# 59          NaN     Burlingame                             Oh My Green
# 60         57.0         Irvine                               Taco Bell
# 66        130.5  San Francisco                               Pinterest
# 71         67.0       San Jose                                     8x8
# 82         56.0      Santa Ana                       Optima Tax Relief
# 84         90.5   Walnut Creek                    CSAA Insurance Group
# 86          NaN       El Cajon                     BioSoft Integrators
# 90         95.0      San Mateo                           Education.com
# 94         83.5  San Francisco                     First Republic Bank
# 95        159.5     Menlo Park                               Robinhood
# 96        115.5        Anaheim                    Reborn Cabinets Inc.
# 106       180.5    Santa Clara                                  Akamai
# 107       174.0  San Francisco                                  Stripe
# 111         NaN  Scotts Valley  Central California Alliance for Health
# 112         NaN  San Francisco                                   Plaid
# 116         NaN        Oakland                                 Everlaw
# 119       156.5  San Francisco                              TrueAccord
# 128       158.0  San Francisco                                   Slack
# 132       143.5      San Mateo                                Fanatics
# 141       124.0    Los Angeles                   L.A. Care Health Plan
# 146       194.5      Sunnyvale                       Walmart eCommerce
# 147       194.5      Sunnyvale                       Walmart eCommerce
# 157       117.0   Agoura Hills                                PennyMac
# 164       160.0    Mill Valley                               Glassdoor
# 172        92.5     Loma Linda    Loma Linda University Medical Center
# 173       213.0      San Bruno                       Walmart eCommerce
# 174       230.0  San Francisco                                  Tapjoy
# 177        96.5      San Diego                      Motive Interactive
# 180       164.0    Santa Clara                      Ericsson-Worldwide
#
#         Designation  Max Salary  Min Salary     Source State  \
# 6      Data Analyst        74.0        56.0  Glassdoor    CA
# 11     Data Analyst       123.0        91.0  Glassdoor    CA
# 13     Data Analyst       124.0       110.0  Glassdoor    CA
# 15     Data Analyst         NaN         NaN  Glassdoor    CA
# 17     Data Analyst       127.0        93.0  Glassdoor    CA
# 18     Data Analyst        66.0        50.0  Glassdoor    CA
# 28     Data Analyst       160.0       123.0  Glassdoor    CA
# 30     Data Analyst       124.0       110.0  Glassdoor    CA
# 36     Data Analyst       127.0        96.0  Glassdoor    CA
# 46     Data Analyst        79.0        50.0  Glassdoor    CA
# 51     Data Analyst        91.0        66.0  Glassdoor    CA
# 59     Data Analyst         NaN         NaN  Glassdoor    CA
# 60     Data Analyst        69.0        45.0  Glassdoor    CA
# 66     Data Analyst       161.0       100.0  Glassdoor    CA
# 71     Data Analyst        79.0        55.0  Glassdoor    CA
# 82     Data Analyst        64.0        48.0  Glassdoor    CA
# 84     Data Analyst       113.0        68.0  Glassdoor    CA
# 86     Data Analyst         NaN         NaN  Glassdoor    CA
# 90     Data Analyst       110.0        80.0  Glassdoor    CA
# 94     Data Analyst        95.0        72.0  Glassdoor    CA
# 95   Data Scientist       185.0       134.0  Glassdoor    CA
# 96   Data Scientist       142.0        89.0  Glassdoor    CA
# 106  Data Scientist       210.0       151.0  Glassdoor    CA
# 107  Data Scientist       202.0       146.0  Glassdoor    CA
# 111  Data Scientist         NaN         NaN  Glassdoor    CA
# 112  Data Scientist         NaN         NaN  Glassdoor    CA
# 116  Data Scientist         NaN         NaN  Glassdoor    CA
# 119  Data Scientist       182.0       131.0  Glassdoor    CA
# 128  Data Scientist       184.0       132.0  Glassdoor    CA
# 132  Data Scientist       167.0       120.0  Glassdoor    CA
# 141  Data Scientist       146.0       102.0  Glassdoor    CA
# 146  Data Scientist       225.0       164.0  Glassdoor    CA
# 147  Data Scientist       225.0       164.0  Glassdoor    CA
# 157  Data Scientist       124.0       110.0  Glassdoor    CA
# 164  Data Scientist       184.0       136.0  Glassdoor    CA
# 172  Data Scientist       108.0        77.0  Glassdoor    CA
# 173  Data Scientist       245.0       181.0  Glassdoor    CA
# 174  Data Scientist       266.0       194.0  Glassdoor    CA
# 177  Data Scientist       114.0        79.0  Glassdoor    CA
# 180  Data Scientist       191.0       137.0  Glassdoor    CA
#
#                                                 Title
# 6                               Research Data Analyst
# 11                                       Data Analyst
# 13                                      Data Engineer
# 15                             Marketing Data Analyst
# 17                 Business Intelligence Data Analyst
# 18                                       Data Analyst
# 28                            Senior Big Data Analyst
# 30                                  Data Engineer ETL
# 36               Data Analyst 1-3, Words with Friends
# 46                     GovernceRiskCompliance Analyst
# 51                                       Data Analyst
# 59                                Senior Data Analyst
# 60                    Data Management Support Analyst
# 66                       Product Analyst, Ads Quality
# 71                                  Marketing Analyst
# 82                                Client Data Analyst
# 84                          Insurance Product Analyst
# 86                                   Analyst, Systems
# 90   Business Intelligence Lead / Senior Data Analyst
# 94                              Data Analyst/Engineer
# 95                                     Data Scientist
# 96                                     Data Scientist
# 106                             Senior Data Scientist
# 107                                    Data Scientist
# 111                                Data Scientist III
# 112                                    Data Scientist
# 116                                    Data Scientist
# 119                                    Data Scientist
# 128                         Data Scientist, Analytics
# 132                                    Data Scientist
# 141                                    Data Scientist
# 146                              Staff Data Scientist
# 147           Staff Data Scientist - Machine Learning
# 157                                     Data Engineer
# 164           Senior Data Scientist, Decision Science
# 172                            Clinical Lab Scientist
# 173                          Principal Data Scientist
# 174                              Staff Data Scientist
# 177                                    Data Scientist
# 180   Senior Machine Learning Engineer/Data Scientist

# %%
grp_city_df = df.groupby('City')
    jobs_city_df = grp_city_df[["State"]].count()
    jobs_city_df = jobs_city_df.rename(
        columns = {"City": "Jobs_Count"}
        ).sort_values(by='Jobs_Count', ascending=False).reset_index()
    json_cities_jobs = jobs_city_df.to_json(orient='records')

# %%
json_data = []
items = ["State"] #, "City", "Company"]
for item in items:
    
    grp_df = df.groupby(item)
    sal_df = grp_df[['Avg Salary']].mean()
    job_df = grp_df[[item]].count().rename(columns = {item: "Jobs Count"})
    merged_table = pd.merge(sal_df, job_df, on= item)
    merged_table = merged_table.sort_values(by=['Jobs Count', 'Avg Salary'], ascending=False).head(20).reset_index()
    
    item_list = []
    sal_list = []
    count_list = []
    item_dict = {}
    for index, row in merged_table.iterrows() :
       # item_list.append(f"{row[item]}") 
       # sal_list.append(row['Avg Salary']) 
       # count_list.append(row['Jobs Count']) 
        item_dict = {"name": row[item],
                     "hours": row['Avg Salary']}
        json_data.append(item_dict)

# %%
# json_data = json_data.replace('"', "'") 
# json.dumps(json_data)
# Out:
# '[{"name": "CA", "hours": 124.20588235294117}, {"name": "NY", "hours": 110.78125}, {"name": "MA", "hours": 110.96666666666667}, {"name": "TX", "hours": 86.65}, {"name": "WA", "hours": 114.4375}, {"name": "VA", "hours": 94.35714285714286}, {"name": "FL", "hours": 75.21428571428571}, {"name": "IL", "hours": 98.25}, {"name": "MI", "hours": 123.5}, {"name": "PA", "hours": 128.33333333333334}, {"name": "GA", "hours": 109.16666666666667}, {"name": "NC", "hours": 101.16666666666667}, {"name": "MN", "hours": 102.75}, {"name": "VT", "hours": 91.25}, {"name": "CO", "hours": 75.0}, {"name": "OR", "hours": 70.5}, {"name": "RI", "hours": 147.0}, {"name": "IN", "hours": 135.0}, {"name": "CT", "hours": 111.5}, {"name": "NM", "hours": 106.0}]'
