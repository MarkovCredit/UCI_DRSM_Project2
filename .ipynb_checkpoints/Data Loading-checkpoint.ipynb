# %%
import pandas as pd
import pymongo

# %%
file = "Resources/data_jobs.csv"
data = pd.read_csv(file, encoding="ISO-8859-1")
#data.head()

# %%
jobs_df = data[["position", "company", "city.x", "state", "lat", "lng", "position_cat"]]\
            .rename(columns = {"position": "Title",
                               "company": "Company",
                               "city.x": "City",
                               "state": "State",
                               "lat": "Latitude",
                               "lng": "Longitude",
                               "position_cat": "Designation"})
jobs_df.head()
# Out:
#                                                Title             Company  \
# 0                               development director             ALS TDI
# 1  an ostentatiously-excitable principal research...  The Hexagon Lavish
# 2                                     data scientist      Xpert Staffing
# 3                                       data analyst      Operation HOPE
# 4  assistant professor -tt - signal processing & ...    Emory University
#
#       City State  Latitude  Longitude     Designation
# 0  Atlanta    GA   33.7627   -84.4231   Data Director
# 1  Atlanta    GA   33.7627   -84.4231  Data Scientist
# 2  Atlanta    GA   33.7627   -84.4231  Data Scientist
# 3  Atlanta    GA   33.7627   -84.4231    Data Analyst
# 4  Atlanta    GA   33.7627   -84.4231  Data Assistant

# %%
#jobs_df["Designation"].value_counts()

# %%
#jobs_df["Company"].value_counts()

# %%
#jobs_df["State"].value_counts()

# %%
jobs_dict = jobs_df.to_dict('index')
jobs_dict
# Out:
# {0: {'Title': 'development director',
#   'Company': 'ALS TDI',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  1: {'Title': 'an ostentatiously-excitable principal research assistant to chief scientist',
#   'Company': 'The Hexagon Lavish',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  2: {'Title': 'data scientist',
#   'Company': 'Xpert Staffing',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  3: {'Title': 'data analyst',
#   'Company': 'Operation HOPE',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  4: {'Title': 'assistant professor -tt - signal processing & machine learning',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Assistant'},
#  5: {'Title': 'manager of data engineering',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  6: {'Title': 'product specialist - periscope, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  7: {'Title': 'junior to mid-level engineer, geologist or environmental scientist',
#   'Company': 'Wood',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  8: {'Title': 'analyst - cib credit research',
#   'Company': 'SunTrust',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  9: {'Title': 'senior associate - cognitive data scientist natural language processing',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  10: {'Title': 'statistical forecast analyst',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  11: {'Title': 'health scientist iii-cpts',
#   'Company': 'Chenega Corporation',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  12: {'Title': 'senior associate, data scientist',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  13: {'Title': 'assistant scientist (ar) som',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  14: {'Title': 'business intelligence data science analyst - supply chain',
#   'Company': 'Newell Brands',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  15: {'Title': 'data scientist',
#   'Company': 'Cotiviti',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  16: {'Title': 'senior structural engineer-transmission & distribution',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  17: {'Title': 'senior mobile developer (ios/android)',
#   'Company': 'Perficient',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  18: {'Title': 'data scientist',
#   'Company': 'Relus Cloud',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  19: {'Title': 'data scientist',
#   'Company': 'Inspire Brands',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  20: {'Title': 'senior electrical engineer',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  21: {'Title': 'sr. manager, full stack development, kpmg tax ignition',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  22: {'Title': 'data scientist',
#   'Company': 'Norfolk Southern Corp',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  23: {'Title': 'data scientist - supply chain',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  24: {'Title': 'data scientist, keying & linking',
#   'Company': 'Equifax',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  25: {'Title': 'data scientist',
#   'Company': 'AirSage',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  26: {'Title': 'data scientist 1 â\x80\x93 ap forensics team',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  27: {'Title': 'data scientist - icl',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  28: {'Title': 'data scientist, online',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  29: {'Title': 'data scientist - consultant level - orlando florida - we will help relocate',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  30: {'Title': 'senior data scientist',
#   'Company': 'Catalina Marketing',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  31: {'Title': 'business intelligence data scientist - supply chain',
#   'Company': 'Newell Brands',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  32: {'Title': 'entry level/junior-level scientist',
#   'Company': 'Kleinfelder, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  33: {'Title': 'scientist - data analysis',
#   'Company': 'AMERICAN CANCER SOCIETY',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  34: {'Title': 'data scientist',
#   'Company': 'SalesLoft',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  35: {'Title': 'data scientist',
#   'Company': 'McKesson',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  36: {'Title': 'data scientist',
#   'Company': 'The Intersect Group',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  37: {'Title': 'health scientist',
#   'Company': 'Centers for Disease Control and Prevention',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  38: {'Title': 'data scientist',
#   'Company': 'OM Partners',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  39: {'Title': 'data scientist - space optimization',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  40: {'Title': 'data science specialist - periscope, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  41: {'Title': 'senior data scientist',
#   'Company': 'Cotiviti',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  42: {'Title': 'manager - data scientist ! orlando!',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  43: {'Title': 'scientist ii',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  44: {'Title': 'lead data scientist',
#   'Company': 'Norfolk Southern Corp',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  45: {'Title': 'senior data scientist',
#   'Company': 'Norfolk Southern Corp',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  46: {'Title': 'data scientist - consultant level - orlando, florida - we will assist with relocation',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  47: {'Title': 'flight safety data analysis fall co-op',
#   'Company': 'Delta Air Lines',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  48: {'Title': 'chief deep learning scientist',
#   'Company': 'YIWEI Medical Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  49: {'Title': 'supervisory health scientist',
#   'Company': 'Centers for Disease Control and Prevention',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  50: {'Title': 'manager - cognitive data scientist natural language processing',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  51: {'Title': 'director, data scientist',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  52: {'Title': 'vp, data scientist- atlanta, ga; charlotte, nc',
#   'Company': 'Bank of America Merchant Services',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  53: {'Title': 'statistical analyst',
#   'Company': 'Hawkins Diagnostics',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  54: {'Title': 'vp, data analytics',
#   'Company': 'TCGplayer',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  55: {'Title': 'lead decision scientist',
#   'Company': 'Moxie Interactive, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  56: {'Title': 'scientist i - sensory panel leader',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  57: {'Title': 'data scientist or data scientist lead ps10268',
#   'Company': 'Anthem, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  58: {'Title': 'lead decision scientist',
#   'Company': 'Moxie',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  59: {'Title': 'senior cyber security data scientist',
#   'Company': 'Bank of America',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  60: {'Title': 'scientist ii/ecologist ii',
#   'Company': 'HNTB Corporation',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  61: {'Title': 'data engineer',
#   'Company': 'Gallup',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  62: {'Title': 'manager, data scientist',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  63: {'Title': 'machine learning / artificial intelligence research scientist',
#   'Company': 'Symantec',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  64: {'Title': 'statistical quantitative analyst',
#   'Company': 'SunTrust',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  65: {'Title': 'research scientist',
#   'Company': 'MacDermid Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  66: {'Title': 'environmental scientist',
#   'Company': 'Tetra Tech',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  67: {'Title': 'scientist, asst bioinformatics',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  68: {'Title': 'research analyst',
#   'Company': 'Evident',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  69: {'Title': 'scientist, asst (ar) som',
#   'Company': 'Emory Healthcare',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  70: {'Title': 'analyst, research',
#   'Company': 'Turner',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  71: {'Title': 'director, nlp data scientist',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  72: {'Title': 'information technology specialist',
#   'Company': 'Centers for Disease Control and Prevention',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Technician'},
#  73: {'Title': 'quantitative analyst',
#   'Company': 'GreenSky',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  74: {'Title': 'data analyst supply chain',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  75: {'Title': 'scientist, asst (ar) som',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  76: {'Title': 'health communications specialist',
#   'Company': 'Eagle Medical Services',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  77: {'Title': 'senior associate, data scientist (nlp/ai)',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  78: {'Title': 'data engineer - gc insights, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  79: {'Title': 'technical evangelist â\x80\x93 database, analytics, and machine learning',
#   'Company': 'Amazon.com',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Technician'},
#  80: {'Title': 'sr scientist ii, analytical science',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  81: {'Title': 'director of data science',
#   'Company': 'Prestige Staffing',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  82: {'Title': 'hiv research scientist',
#   'Company': 'Eagle Medical Services',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  83: {'Title': 'si coe iot data modeling architect',
#   'Company': 'Xylem',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  84: {'Title': 'research scientist',
#   'Company': 'PreVisor',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  85: {'Title': 'azure data scientist, manager',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  86: {'Title': 'associate scientist, som',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  87: {'Title': 'data engineer, scala',
#   'Company': 'CapTech Consulting',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  88: {'Title': 'director, financial services - data scientist',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  89: {'Title': 'regulatory labeling, advertising and promotion scientist',
#   'Company': 'UCB',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  90: {'Title': 'data & analytics developer',
#   'Company': 'SunTrust',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  91: {'Title': 'product development scientist',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  92: {'Title': 'research scientist i',
#   'Company': 'Georgia State University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  93: {'Title': 'data scientist - senior consultant - orlando, florida',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  94: {'Title': 'lead r & d engineer/scientist',
#   'Company': 'Honeywell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  95: {'Title': 'quantitative finance analyst',
#   'Company': 'Bank of America',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  96: {'Title': 'advertiser research analyst',
#   'Company': 'Cox Media Group',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  97: {'Title': 'manager, data scientist (ml/nlp) -- financial services',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  98: {'Title': 'data science instructor',
#   'Company': 'General Assembly',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  99: {'Title': 'research informatics analyst',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  100: {'Title': 'enterprise data analyst & data engineer',
#   'Company': 'Novelis',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  101: {'Title': 'supply chain data science consultant',
#   'Company': 'Accenture',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  102: {'Title': 'public health communications specialist',
#   'Company': '2M Research Services',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  103: {'Title': 'communications specialist',
#   'Company': 'Loyal',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  104: {'Title': '2018 - health research analyst 2 - new',
#   'Company': 'Northrop Grumman',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  105: {'Title': 'business intelligence engineer',
#   'Company': 'Amazon.com',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  106: {'Title': 'staff research scientist vii: informational interpretation researcher',
#   'Company': 'The Hexagon Lavish',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  107: {'Title': 'scientist, asst (ar) school of medicine (som)',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  108: {'Title': 'entry level geologist, engineer or environmental scientist',
#   'Company': 'Wood',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  109: {'Title': 'regulatory labeling, advertising and promotion scientist',
#   'Company': 'UCB S.A.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  110: {'Title': 'quantitative analyst',
#   'Company': 'Voya Financial',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  111: {'Title': 'director, data scientist -- financial services/insurance',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  112: {'Title': 'supervisory epidemiologist',
#   'Company': 'Centers for Disease Control and Prevention',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  113: {'Title': 'quantitative finance analyst/c++ developer',
#   'Company': 'Bank of America',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  114: {'Title': 'jr microbiologist - cdc',
#   'Company': 'G2S Corporation',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  115: {'Title': 'azure data scientist, senior associate',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  116: {'Title': 'research analyst',
#   'Company': 'Epiq Systems, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  117: {'Title': 'coding research analyst',
#   'Company': 'Zelis Healthcare',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  118: {'Title': 'data science manager- atlanta',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  119: {'Title': 'quantitative analyst',
#   'Company': 'Intercontinental Exchange',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  120: {'Title': 'data visualization software engineer',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  121: {'Title': 'business intelligence analyst, people analytics & measurement',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  122: {'Title': 'mid data scientist - machine learning',
#   'Company': 'Elev8 Hire Solutions',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  123: {'Title': 'vendor research analyst',
#   'Company': 'Northside Hospital',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  124: {'Title': 'big data sw engineer',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  125: {'Title': 'senior scientist, content science',
#   'Company': 'Pandora Media, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  126: {'Title': 'sponsored research financial analyst',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  127: {'Title': 'supply chain data science manager',
#   'Company': 'Accenture',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  128: {'Title': 'director hr data and insights',
#   'Company': 'WestRock',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  129: {'Title': 'bi quantitative analyst',
#   'Company': "Children's Healthcare of Atlanta",
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  130: {'Title': 'research specialist',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  131: {'Title': 'associate product designer',
#   'Company': 'IBM',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  132: {'Title': 'ecologist',
#   'Company': 'VHB',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  133: {'Title': 'tech fall 2018 intern - machine learning',
#   'Company': 'Turner',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Technician'},
#  134: {'Title': 'r&d innovation engineer - video analytics/machine learning',
#   'Company': 'Honeywell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  135: {'Title': 'lead data engineer',
#   'Company': 'ThoughtWorks',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  136: {'Title': 'data analytics engineer / big data engineer',
#   'Company': 'UST Global Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  137: {'Title': 'corporate investment quantitative finance analyst',
#   'Company': 'Bank of America',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  138: {'Title': 'malware analyst',
#   'Company': 'ICF',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  139: {'Title': 'principal research scientist i: informational library architect extraordinaire',
#   'Company': 'The Hexagon Lavish',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  140: {'Title': 'market research analyst',
#   'Company': 'SKIM',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  141: {'Title': 'manager, statistical modeling & analytics',
#   'Company': 'Piedmont Healthcare',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  142: {'Title': 'senior scientist, advertising',
#   'Company': 'Pandora Media, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  143: {'Title': 'junior specialist - periscope advanced insights growth mapping, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  144: {'Title': 'full stack developer',
#   'Company': 'GreenSky',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  145: {'Title': 'senior associate, data scientist/statistics -- financial services',
#   'Company': 'KPMG',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  146: {'Title': 'assistant scientist - metabolics division lead',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  147: {'Title': 'senior data engineer, next big sound',
#   'Company': 'Pandora Media, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  148: {'Title': 'market research analyst',
#   'Company': 'ResMed',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  149: {'Title': 'biomedical engineering: faculty position - open rank (asst or assoc professor)',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  150: {'Title': 'solutions consultant',
#   'Company': 'Oversight Systems',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  151: {'Title': 'senior scientist, immunology',
#   'Company': 'GeoVax, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  152: {'Title': 'director, data science (ps6695)',
#   'Company': 'Anthem, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  153: {'Title': 'a vigorously-charged scientific programmer',
#   'Company': 'The Hexagon Lavish',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  154: {'Title': 'software engineer',
#   'Company': 'FraudScope',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  155: {'Title': 'sr. data scientist â\x80\x93 market research',
#   'Company': 'Analytic Recruiting',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  156: {'Title': 'director of software',
#   'Company': 'Bionic Sciences Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Director'},
#  157: {'Title': 'certifying scientist / quantitation scientist',
#   'Company': 'Lighthouse Lab Services',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  158: {'Title': 'senior data scientist',
#   'Company': 'Smith Hanley Associates',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  159: {'Title': 'sr manager - data & analytics',
#   'Company': 'General Electric',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  160: {'Title': 'big data engineer (mid to senior level)',
#   'Company': 'GreenSky',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  161: {'Title': 'data scientist',
#   'Company': 'Xpect SVC, LLC',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  162: {'Title': 'data science - senior consultant',
#   'Company': 'Capgemini',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  163: {'Title': 'adolescent health evaluation specialist',
#   'Company': 'ICF',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  164: {'Title': 'windows programmer / software engineer - intermediate/senior -elsys -7332',
#   'Company': 'The Goal Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  165: {'Title': 'sr. data engineer',
#   'Company': 'Optomi',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  166: {'Title': 'team lead â\x80\x93 informatics. sensus usa inc. atlanta, georgia',
#   'Company': 'Xylem',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  167: {'Title': 'electrical / substation design engineer',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  168: {'Title': 'windows programmer / software engineer (advanced degree) - elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  169: {'Title': 'electrical/computer engineer - eosl',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  170: {'Title': 'windows programmer / software engineer - entry/ intermediate -elsys - 7333',
#   'Company': 'The Goal Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  171: {'Title': 'principal research scientist',
#   'Company': 'Headway Workforce Solutions',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  172: {'Title': 'senior business intelligence analyst',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  173: {'Title': 'senior software engineer, machine learning',
#   'Company': 'Pandora Media, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  174: {'Title': 'scientist',
#   'Company': 'R&D Partners',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  175: {'Title': 'staff cad technician',
#   'Company': 'Golder Associates',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Technician'},
#  176: {'Title': 'engineering co-op',
#   'Company': 'Golder Associates',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  177: {'Title': 'associate manager, agile paid media',
#   'Company': 'The Home Depot',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  178: {'Title': 'category manager',
#   'Company': 'JUUL Labs',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  179: {'Title': 'fpga hardware researcher - cipher',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  180: {'Title': 'senior marketing research analyst',
#   'Company': 'HD Supply',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  181: {'Title': 'right-of-way acquisition manager | atlanta, ga',
#   'Company': 'Gresham, Smith and Partners.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  182: {'Title': 'associate research scientist',
#   'Company': 'R&D Partners',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  183: {'Title': 'entry-level electrical engineer',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  184: {'Title': 'staff software engineer',
#   'Company': 'General Electric',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  185: {'Title': 'principal engineer',
#   'Company': 'Cotiviti',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  186: {'Title': 'devops engineer - elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  187: {'Title': 'senior analyst, payments study - gc insights, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  188: {'Title': 'senior analyst - multi-client benchmarks, gc insights - new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  189: {'Title': 'bi - analytics - cloud platform operations analyst',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  190: {'Title': 'sr quantitative finance analyst/c++ developer',
#   'Company': 'Bank of America',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  191: {'Title': 'business analytics consultant sr',
#   'Company': 'PNC Financial Services Group',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  192: {'Title': 'various professional, technical, administrative and scientific positions supporting a public health client',
#   'Company': 'Alaka`ina Foundation Family of Companies',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  193: {'Title': 'senior engineer ii, packaging research',
#   'Company': 'The Coca-Cola Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  194: {'Title': 'pediatrics â\x80\x93 dir. pediatric clinical and translational research',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  195: {'Title': 'avionics system designer - elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  196: {'Title': 'business development manager (southeast region)',
#   'Company': 'Catapult Sports',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  197: {'Title': 'senior research analyst and team lead - hr insights - bersin',
#   'Company': 'Deloitte',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  198: {'Title': 'landscape architect (graduate)',
#   'Company': 'Jacobs',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  199: {'Title': 'implementation engineer (machine learning/data analytics)',
#   'Company': 'eHire, LLC',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  200: {'Title': 'senior sales account executive',
#   'Company': 'Clear Story Data',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  201: {'Title': 'post-doctoral fellowship training program in cancer epidemiology, prevention and survivorship',
#   'Company': 'AMERICAN CANCER SOCIETY',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  202: {'Title': 'senior software researcher - cipher',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  203: {'Title': 'configuration management/quality assurance manager -atas',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  204: {'Title': 'practice technology regional bim manager (east region)',
#   'Company': 'HKS, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  205: {'Title': 'windows programmer / software engineer- elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  206: {'Title': 'cyber security systems engineer',
#   'Company': 'ICF',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  207: {'Title': 'technical product manager â\x80\x93 secureworks â\x80\x93 austin, tx, atlanta, ga, d.c. metro, or remote',
#   'Company': 'DELL',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  208: {'Title': 'data scientist',
#   'Company': 'Matrix Resources',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  209: {'Title': 'seniorâ\xa0fpgaâ\xa0hardwareâ\xa0researcher - cipher',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  210: {'Title': 'environmental project engineer - ccr/fly ash npdes',
#   'Company': 'Stantec',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  211: {'Title': 'technical lead data engineer/architect',
#   'Company': 'Beacon Hill Technologies',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Technician'},
#  212: {'Title': 'post-doctoral fellow- medical imaging, machine learning and ct physics',
#   'Company': 'Emory University',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Machine Learning Engineer'},
#  213: {'Title': 'avionics system designer (advanced degree) - elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  214: {'Title': 'branchâ\xa0headâ\xa0forâ\xa0fpgaâ\xa0hardwareâ\xa0researchâ\xa0andâ\xa0development - cipher',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Research Analyst/Scientist'},
#  215: {'Title': 'sr. staff enterprise application engineer',
#   'Company': 'General Electric',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  216: {'Title': 'commercial construction market leader â\x80\x93 global facilities',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  217: {'Title': 'senior firmware engineer - elsys',
#   'Company': 'Georgia Tech Research Institute',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  218: {'Title': 'senior staff-national tax office',
#   'Company': 'Crowe',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Other'},
#  219: {'Title': 'senior analyst - marketing research',
#   'Company': 'GEORGIA-PACIFIC',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  220: {'Title': 'sr. product manager â\x80\x93 secureworks â\x80\x93 austin, tx, atlanta, ga, d.c. metro, or remote',
#   'Company': 'DELL',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Manager'},
#  221: {'Title': 'senior web developer',
#   'Company': 'Perficient',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Developer'},
#  222: {'Title': 'senior software engineer',
#   'Company': 'Feedzai',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  223: {'Title': 'sr staff software engineer',
#   'Company': 'General Electric',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Engineer'},
#  224: {'Title': 'data scientist',
#   'Company': 'Elavon, Inc.',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  225: {'Title': 'senior analyst - gc insights, new ventures',
#   'Company': 'McKinsey & Company',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  226: {'Title': 'assistant architect',
#   'Company': 'Burns & McDonnell',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Assistant'},
#  227: {'Title': 'senior market research analyst',
#   'Company': 'Pearson',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Analyst'},
#  228: {'Title': 'advanced analytics consultant - machine learning',
#   'Company': 'Slalom Consulting',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Consultant'},
#  229: {'Title': 'data scientist',
#   'Company': 'Cardinal Solutions',
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Latitude': 33.7627,
#   'Longitude': -84.4231,
#   'Designation': 'Data Scientist'},
#  230: {'Title': 'research epidemiologist',
# ...
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Technician'},
#  931: {'Title': 'water utility financial analyst & research fellow, institute for sustainable energy, questrom school of business',
#   'Company': 'Boston University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Analyst'},
#  932: {'Title': 'senior scientist analytical development',
#   'Company': 'Vertex',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Scientist'},
#  933: {'Title': 'senior bioinformatician / 40 hours / day / bwh genetics',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  934: {'Title': 'bwh-technical research assistant ii-40-day-pathology',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  935: {'Title': 'technical research assistant i / 40 hour / day / bwh - channing division of network medicine',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  936: {'Title': 'director of statistical genetics',
#   'Company': 'Merck',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Director'},
#  937: {'Title': 'senior machine learning / artificial intelligence engineer',
#   'Company': 'Cambridge Consultants',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  938: {'Title': 'senior quantitative research analyst, vp',
#   'Company': 'State Street',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Analyst'},
#  939: {'Title': 'postdoctoral research associate, college of arts, media and design',
#   'Company': 'Northeastern University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  940: {'Title': 'senior product manager, sort & recommendations',
#   'Company': 'Wayfair',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  941: {'Title': 'product manager',
#   'Company': 'TekPartners, A P2P Company',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  942: {'Title': 'principal, education | science | tech',
#   'Company': 'HDR',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Scientist'},
#  943: {'Title': 'senior user experience designer',
#   'Company': 'Cogito Corporation',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  944: {'Title': 'technical research assistant i / 40 hour / day / bwh - hematology',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  945: {'Title': 'senior marketing analyst - python',
#   'Company': 'Harnham',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Analyst'},
#  946: {'Title': 'software developer in test at ai & machine learning customer engagement startup',
#   'Company': 'Workbridge Associates',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Developer'},
#  947: {'Title': 'machine learning architect - algorithms',
#   'Company': 'NDT.com',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Machine Learning Engineer'},
#  948: {'Title': 'technical program manager, education programs',
#   'Company': 'Autodesk',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  949: {'Title': 'senior machine learning / artificial intelligence engineer',
#   'Company': 'Cambridge Consultants Ltd',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  950: {'Title': 'senior manager of statistical programming',
#   'Company': 'Odonate Therapeutics',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  951: {'Title': 'back-end software engineer at travel startup in cambridge',
#   'Company': 'Workbridge Associates',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  952: {'Title': 'biostatistician ii - heart center clinical research program',
#   'Company': "Boston Children's Hospital",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  953: {'Title': 'executive medical director pv',
#   'Company': 'Takeda Pharmaceutical',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Director'},
#  954: {'Title': 'software engineer - computer vision/deep learning',
#   'Company': 'Harnham',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  955: {'Title': 'postdoctoral associate, questrom school of business and bu law school,social innovation on drug resistance program',
#   'Company': 'Boston University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Developer'},
#  956: {'Title': 'technical marketing manager, infrastructure',
#   'Company': 'Autodesk',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  957: {'Title': 'research associate, sr.',
#   'Company': 'Beth Israel Deaconess Medical Center',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  958: {'Title': 'associate scientific director',
#   'Company': 'Takeda Pharmaceutical',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Director'},
#  959: {'Title': 'software product manager',
#   'Company': 'Indigo',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  960: {'Title': 'machine learning / a.i. software engineer',
#   'Company': 'Resource Technology Partners',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  961: {'Title': 'big data engineer, technical lead (hands on, individual contributor)',
#   'Company': 'Fidelity Investments',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Technician'},
#  962: {'Title': 'software engineer (java / machine learning)',
#   'Company': 'Resource Technology Partners',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  963: {'Title': 'technical research assistant ii / 40 hours / day / bwh - rheumatology',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  964: {'Title': 'technical research assistant i / 40 hours / day / bwh - cardiovascular medicine',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  965: {'Title': 'principal product manager technical, amazon search (l7)',
#   'Company': 'Amazon.com',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  966: {'Title': 'postdoctoral associate, college of engineering and school of public health, social innovation on drug resistance program',
#   'Company': 'Boston University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Developer'},
#  967: {'Title': 'research technologist - transplant surgery',
#   'Company': 'Massachusetts General Hospital(MGH)',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  968: {'Title': 'sr. radar systems engineer/machine learning researcher',
#   'Company': 'Riverside Research',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  969: {'Title': 'principal design assurance / quality engineer',
#   'Company': 'Cambridge Consultants',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  970: {'Title': 'senior hr manager',
#   'Company': 'Partners HealthCare(PHS)',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  971: {'Title': 'technical research assistant ii / 40 hour / day / channing division of network medicine',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  972: {'Title': 'technical research assistant ii / 40 hours / day / bwh surgery research',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  973: {'Title': 'research fellow - pediatric oncology/crompton lab',
#   'Company': 'Dana-Farber Cancer Institute',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  974: {'Title': 'senior software engineer, data & analytics',
#   'Company': 'Indigo',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Engineer'},
#  975: {'Title': 'downstream process development scientist',
#   'Company': 'AP Staffing',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Scientist'},
#  976: {'Title': 'flow core manager/lead research technologist',
#   'Company': "Boston Children's Hospital",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  977: {'Title': 'senior scientist chemical and materials engineering',
#   'Company': 'Vertex',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Scientist'},
#  978: {'Title': 'senior software engineer, data science platform',
#   'Company': 'Indigo',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Scientist'},
#  979: {'Title': 'immunologist',
#   'Company': 'Commonwealth Sciences',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  980: {'Title': 'research associate ii, abiotic screening',
#   'Company': 'Indigo',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  981: {'Title': 'rn flow /operations manager / 40 hour / day shift - bwh - primary care - main campus',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  982: {'Title': 'high throughput screening lead',
#   'Company': 'Indigo',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  983: {'Title': 'sr. technical/40/hours/day shift/research path/bwh',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  984: {'Title': 'research technician ii - surgical oncology',
#   'Company': 'Massachusetts General Hospital(MGH)',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  985: {'Title': 'research technician - microbiology, school of medicine',
#   'Company': 'TUFTS University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  986: {'Title': 'senior equity research analyst / client portfolio manager',
#   'Company': 'Cambridge Trust Company',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  987: {'Title': 'senior product manager, datarobot apps',
#   'Company': 'DataRobot',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  988: {'Title': 'senior technical recruiter',
#   'Company': 'BAIN & COMPANY',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Technician'},
#  989: {'Title': 'group leader, bioinformatics',
#   'Company': 'Massachusetts General Hospital(MGH)',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  990: {'Title': 'senior software developer',
#   'Company': 'Jenzabar, Inc',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Developer'},
#  991: {'Title': 'front-end web developer',
#   'Company': 'Harvard University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Developer'},
#  992: {'Title': 'research assistant iii - microfluidic cell based assays and drug testing',
#   'Company': 'Harvard University',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  993: {'Title': 'ux designer',
#   'Company': 'Solidus Technical Solutions',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  994: {'Title': 'technical support specialist - center for engineering in medicine',
#   'Company': 'Massachusetts General Hospital(MGH)',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Technician'},
#  995: {'Title': 'technical research assistant ii / 40 hour / day / bwh - renal medicine',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  996: {'Title': 'engineering manager',
#   'Company': 'Twitter',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Manager'},
#  997: {'Title': 'technical research assistant ii / day / 40 hours / bwh neurology',
#   'Company': "Brigham & Women's Hospital(BWH)",
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Research Analyst/Scientist'},
#  998: {'Title': 'senior research analyst - research and economics',
#   'Company': 'Burning Glass Technologies',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Data Analyst'},
#  999: {'Title': 'squad leader: planning initiation & engagement - boston, ma or durham, nc',
#   'Company': 'Fidelity Investments',
#   'City': 'Boston',
#   'State': 'MA',
#   'Latitude': 42.3189,
#   'Longitude': -71.0838,
#   'Designation': 'Other'},
#  ...}

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.jobs_db
db.job_listings.drop()
jobs_mongo = db.job_listings

# %%
for i in range(len(jobs_dict)):
    jobs_mongo.insert_one(jobs_dict[i])

# %%
listings = db.job_listings.find()
for listing in listings:
    print(listing)
# Out:
# {'_id': ObjectId('5c04558297a998779b5265df'), 'Title': 'development director', 'Company': 'ALS TDI', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b5265e0'), 'Title': 'an ostentatiously-excitable principal research assistant to chief scientist', 'Company': 'The Hexagon Lavish', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265e1'), 'Title': 'data scientist', 'Company': 'Xpert Staffing', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265e2'), 'Title': 'data analyst', 'Company': 'Operation HOPE', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b5265e3'), 'Title': 'assistant professor -tt - signal processing & machine learning', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Assistant'}
# {'_id': ObjectId('5c04558297a998779b5265e4'), 'Title': 'manager of data engineering', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b5265e5'), 'Title': 'product specialist - periscope, new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b5265e6'), 'Title': 'junior to mid-level engineer, geologist or environmental scientist', 'Company': 'Wood', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265e7'), 'Title': 'analyst - cib credit research', 'Company': 'SunTrust', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b5265e8'), 'Title': 'senior associate - cognitive data scientist natural language processing', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265e9'), 'Title': 'statistical forecast analyst', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b5265ea'), 'Title': 'health scientist iii-cpts', 'Company': 'Chenega Corporation', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265eb'), 'Title': 'senior associate, data scientist', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265ec'), 'Title': 'assistant scientist (ar) som', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265ed'), 'Title': 'business intelligence data science analyst - supply chain', 'Company': 'Newell Brands', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b5265ee'), 'Title': 'data scientist', 'Company': 'Cotiviti', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265ef'), 'Title': 'senior structural engineer-transmission & distribution', 'Company': 'Burns & McDonnell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b5265f0'), 'Title': 'senior mobile developer (ios/android)', 'Company': 'Perficient', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b5265f1'), 'Title': 'data scientist', 'Company': 'Relus Cloud', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f2'), 'Title': 'data scientist', 'Company': 'Inspire Brands', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f3'), 'Title': 'senior electrical engineer', 'Company': 'Burns & McDonnell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b5265f4'), 'Title': 'sr. manager, full stack development, kpmg tax ignition', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b5265f5'), 'Title': 'data scientist', 'Company': 'Norfolk Southern Corp', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f6'), 'Title': 'data scientist - supply chain', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f7'), 'Title': 'data scientist, keying & linking', 'Company': 'Equifax', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f8'), 'Title': 'data scientist', 'Company': 'AirSage', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265f9'), 'Title': 'data scientist 1 â\x80\x93 ap forensics team', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265fa'), 'Title': 'data scientist - icl', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265fb'), 'Title': 'data scientist, online', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265fc'), 'Title': 'data scientist - consultant level - orlando florida - we will help relocate', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b5265fd'), 'Title': 'senior data scientist', 'Company': 'Catalina Marketing', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265fe'), 'Title': 'business intelligence data scientist - supply chain', 'Company': 'Newell Brands', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5265ff'), 'Title': 'entry level/junior-level scientist', 'Company': 'Kleinfelder, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526600'), 'Title': 'scientist - data analysis', 'Company': 'AMERICAN CANCER SOCIETY', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526601'), 'Title': 'data scientist', 'Company': 'SalesLoft', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526602'), 'Title': 'data scientist', 'Company': 'McKesson', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526603'), 'Title': 'data scientist', 'Company': 'The Intersect Group', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526604'), 'Title': 'health scientist', 'Company': 'Centers for Disease Control and Prevention', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526605'), 'Title': 'data scientist', 'Company': 'OM Partners', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526606'), 'Title': 'data scientist - space optimization', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526607'), 'Title': 'data science specialist - periscope, new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526608'), 'Title': 'senior data scientist', 'Company': 'Cotiviti', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526609'), 'Title': 'manager - data scientist ! orlando!', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b52660a'), 'Title': 'scientist ii', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52660b'), 'Title': 'lead data scientist', 'Company': 'Norfolk Southern Corp', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52660c'), 'Title': 'senior data scientist', 'Company': 'Norfolk Southern Corp', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52660d'), 'Title': 'data scientist - consultant level - orlando, florida - we will assist with relocation', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b52660e'), 'Title': 'flight safety data analysis fall co-op', 'Company': 'Delta Air Lines', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b52660f'), 'Title': 'chief deep learning scientist', 'Company': 'YIWEI Medical Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526610'), 'Title': 'supervisory health scientist', 'Company': 'Centers for Disease Control and Prevention', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526611'), 'Title': 'manager - cognitive data scientist natural language processing', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526612'), 'Title': 'director, data scientist', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526613'), 'Title': 'vp, data scientist- atlanta, ga; charlotte, nc', 'Company': 'Bank of America Merchant Services', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526614'), 'Title': 'statistical analyst', 'Company': 'Hawkins Diagnostics', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526615'), 'Title': 'vp, data analytics', 'Company': 'TCGplayer', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526616'), 'Title': 'lead decision scientist', 'Company': 'Moxie Interactive, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526617'), 'Title': 'scientist i - sensory panel leader', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526618'), 'Title': 'data scientist or data scientist lead ps10268', 'Company': 'Anthem, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526619'), 'Title': 'lead decision scientist', 'Company': 'Moxie', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52661a'), 'Title': 'senior cyber security data scientist', 'Company': 'Bank of America', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52661b'), 'Title': 'scientist ii/ecologist ii', 'Company': 'HNTB Corporation', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52661c'), 'Title': 'data engineer', 'Company': 'Gallup', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b52661d'), 'Title': 'manager, data scientist', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b52661e'), 'Title': 'machine learning / artificial intelligence research scientist', 'Company': 'Symantec', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52661f'), 'Title': 'statistical quantitative analyst', 'Company': 'SunTrust', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526620'), 'Title': 'research scientist', 'Company': 'MacDermid Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526621'), 'Title': 'environmental scientist', 'Company': 'Tetra Tech', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526622'), 'Title': 'scientist, asst bioinformatics', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526623'), 'Title': 'research analyst', 'Company': 'Evident', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526624'), 'Title': 'scientist, asst (ar) som', 'Company': 'Emory Healthcare', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526625'), 'Title': 'analyst, research', 'Company': 'Turner', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526626'), 'Title': 'director, nlp data scientist', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526627'), 'Title': 'information technology specialist', 'Company': 'Centers for Disease Control and Prevention', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Technician'}
# {'_id': ObjectId('5c04558297a998779b526628'), 'Title': 'quantitative analyst', 'Company': 'GreenSky', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526629'), 'Title': 'data analyst supply chain', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52662a'), 'Title': 'scientist, asst (ar) som', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52662b'), 'Title': 'health communications specialist', 'Company': 'Eagle Medical Services', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b52662c'), 'Title': 'senior associate, data scientist (nlp/ai)', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52662d'), 'Title': 'data engineer - gc insights, new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b52662e'), 'Title': 'technical evangelist â\x80\x93 database, analytics, and machine learning', 'Company': 'Amazon.com', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Technician'}
# {'_id': ObjectId('5c04558297a998779b52662f'), 'Title': 'sr scientist ii, analytical science', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526630'), 'Title': 'director of data science', 'Company': 'Prestige Staffing', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526631'), 'Title': 'hiv research scientist', 'Company': 'Eagle Medical Services', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526632'), 'Title': 'si coe iot data modeling architect', 'Company': 'Xylem', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526633'), 'Title': 'research scientist', 'Company': 'PreVisor', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526634'), 'Title': 'azure data scientist, manager', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526635'), 'Title': 'associate scientist, som', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526636'), 'Title': 'data engineer, scala', 'Company': 'CapTech Consulting', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526637'), 'Title': 'director, financial services - data scientist', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526638'), 'Title': 'regulatory labeling, advertising and promotion scientist', 'Company': 'UCB', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526639'), 'Title': 'data & analytics developer', 'Company': 'SunTrust', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b52663a'), 'Title': 'product development scientist', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52663b'), 'Title': 'research scientist i', 'Company': 'Georgia State University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52663c'), 'Title': 'data scientist - senior consultant - orlando, florida', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b52663d'), 'Title': 'lead r & d engineer/scientist', 'Company': 'Honeywell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52663e'), 'Title': 'quantitative finance analyst', 'Company': 'Bank of America', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52663f'), 'Title': 'advertiser research analyst', 'Company': 'Cox Media Group', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526640'), 'Title': 'manager, data scientist (ml/nlp) -- financial services', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526641'), 'Title': 'data science instructor', 'Company': 'General Assembly', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526642'), 'Title': 'research informatics analyst', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526643'), 'Title': 'enterprise data analyst & data engineer', 'Company': 'Novelis', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526644'), 'Title': 'supply chain data science consultant', 'Company': 'Accenture', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b526645'), 'Title': 'public health communications specialist', 'Company': '2M Research Services', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526646'), 'Title': 'communications specialist', 'Company': 'Loyal', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526647'), 'Title': '2018 - health research analyst 2 - new', 'Company': 'Northrop Grumman', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526648'), 'Title': 'business intelligence engineer', 'Company': 'Amazon.com', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526649'), 'Title': 'staff research scientist vii: informational interpretation researcher', 'Company': 'The Hexagon Lavish', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52664a'), 'Title': 'scientist, asst (ar) school of medicine (som)', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52664b'), 'Title': 'entry level geologist, engineer or environmental scientist', 'Company': 'Wood', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52664c'), 'Title': 'regulatory labeling, advertising and promotion scientist', 'Company': 'UCB S.A.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52664d'), 'Title': 'quantitative analyst', 'Company': 'Voya Financial', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52664e'), 'Title': 'director, data scientist -- financial services/insurance', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b52664f'), 'Title': 'supervisory epidemiologist', 'Company': 'Centers for Disease Control and Prevention', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526650'), 'Title': 'quantitative finance analyst/c++ developer', 'Company': 'Bank of America', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526651'), 'Title': 'jr microbiologist - cdc', 'Company': 'G2S Corporation', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526652'), 'Title': 'azure data scientist, senior associate', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526653'), 'Title': 'research analyst', 'Company': 'Epiq Systems, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526654'), 'Title': 'coding research analyst', 'Company': 'Zelis Healthcare', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526655'), 'Title': 'data science manager- atlanta', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526656'), 'Title': 'quantitative analyst', 'Company': 'Intercontinental Exchange', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526657'), 'Title': 'data visualization software engineer', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526658'), 'Title': 'business intelligence analyst, people analytics & measurement', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526659'), 'Title': 'mid data scientist - machine learning', 'Company': 'Elev8 Hire Solutions', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52665a'), 'Title': 'vendor research analyst', 'Company': 'Northside Hospital', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52665b'), 'Title': 'big data sw engineer', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b52665c'), 'Title': 'senior scientist, content science', 'Company': 'Pandora Media, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52665d'), 'Title': 'sponsored research financial analyst', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52665e'), 'Title': 'supply chain data science manager', 'Company': 'Accenture', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b52665f'), 'Title': 'director hr data and insights', 'Company': 'WestRock', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526660'), 'Title': 'bi quantitative analyst', 'Company': "Children's Healthcare of Atlanta", 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526661'), 'Title': 'research specialist', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558297a998779b526662'), 'Title': 'associate product designer', 'Company': 'IBM', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526663'), 'Title': 'ecologist', 'Company': 'VHB', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526664'), 'Title': 'tech fall 2018 intern - machine learning', 'Company': 'Turner', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Technician'}
# {'_id': ObjectId('5c04558297a998779b526665'), 'Title': 'r&d innovation engineer - video analytics/machine learning', 'Company': 'Honeywell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526666'), 'Title': 'lead data engineer', 'Company': 'ThoughtWorks', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526667'), 'Title': 'data analytics engineer / big data engineer', 'Company': 'UST Global Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526668'), 'Title': 'corporate investment quantitative finance analyst', 'Company': 'Bank of America', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526669'), 'Title': 'malware analyst', 'Company': 'ICF', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52666a'), 'Title': 'principal research scientist i: informational library architect extraordinaire', 'Company': 'The Hexagon Lavish', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52666b'), 'Title': 'market research analyst', 'Company': 'SKIM', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52666c'), 'Title': 'manager, statistical modeling & analytics', 'Company': 'Piedmont Healthcare', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b52666d'), 'Title': 'senior scientist, advertising', 'Company': 'Pandora Media, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52666e'), 'Title': 'junior specialist - periscope advanced insights growth mapping, new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b52666f'), 'Title': 'full stack developer', 'Company': 'GreenSky', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b526670'), 'Title': 'senior associate, data scientist/statistics -- financial services', 'Company': 'KPMG', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526671'), 'Title': 'assistant scientist - metabolics division lead', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526672'), 'Title': 'senior data engineer, next big sound', 'Company': 'Pandora Media, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526673'), 'Title': 'market research analyst', 'Company': 'ResMed', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526674'), 'Title': 'biomedical engineering: faculty position - open rank (asst or assoc professor)', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526675'), 'Title': 'solutions consultant', 'Company': 'Oversight Systems', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b526676'), 'Title': 'senior scientist, immunology', 'Company': 'GeoVax, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526677'), 'Title': 'director, data science (ps6695)', 'Company': 'Anthem, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b526678'), 'Title': 'a vigorously-charged scientific programmer', 'Company': 'The Hexagon Lavish', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526679'), 'Title': 'software engineer', 'Company': 'FraudScope', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b52667a'), 'Title': 'sr. data scientist â\x80\x93 market research', 'Company': 'Analytic Recruiting', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52667b'), 'Title': 'director of software', 'Company': 'Bionic Sciences Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558297a998779b52667c'), 'Title': 'certifying scientist / quantitation scientist', 'Company': 'Lighthouse Lab Services', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52667d'), 'Title': 'senior data scientist', 'Company': 'Smith Hanley Associates', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52667e'), 'Title': 'sr manager - data & analytics', 'Company': 'General Electric', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b52667f'), 'Title': 'big data engineer (mid to senior level)', 'Company': 'GreenSky', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526680'), 'Title': 'data scientist', 'Company': 'Xpect SVC, LLC', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526681'), 'Title': 'data science - senior consultant', 'Company': 'Capgemini', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b526682'), 'Title': 'adolescent health evaluation specialist', 'Company': 'ICF', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526683'), 'Title': 'windows programmer / software engineer - intermediate/senior -elsys -7332', 'Company': 'The Goal Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b526684'), 'Title': 'sr. data engineer', 'Company': 'Optomi', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526685'), 'Title': 'team lead â\x80\x93 informatics. sensus usa inc. atlanta, georgia', 'Company': 'Xylem', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b526686'), 'Title': 'electrical / substation design engineer', 'Company': 'Burns & McDonnell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526687'), 'Title': 'windows programmer / software engineer (advanced degree) - elsys', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b526688'), 'Title': 'electrical/computer engineer - eosl', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526689'), 'Title': 'windows programmer / software engineer - entry/ intermediate -elsys - 7333', 'Company': 'The Goal Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b52668a'), 'Title': 'principal research scientist', 'Company': 'Headway Workforce Solutions', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52668b'), 'Title': 'senior business intelligence analyst', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52668c'), 'Title': 'senior software engineer, machine learning', 'Company': 'Pandora Media, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b52668d'), 'Title': 'scientist', 'Company': 'R&D Partners', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b52668e'), 'Title': 'staff cad technician', 'Company': 'Golder Associates', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Technician'}
# {'_id': ObjectId('5c04558297a998779b52668f'), 'Title': 'engineering co-op', 'Company': 'Golder Associates', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526690'), 'Title': 'associate manager, agile paid media', 'Company': 'The Home Depot', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526691'), 'Title': 'category manager', 'Company': 'JUUL Labs', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526692'), 'Title': 'fpga hardware researcher - cipher', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558297a998779b526693'), 'Title': 'senior marketing research analyst', 'Company': 'HD Supply', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b526694'), 'Title': 'right-of-way acquisition manager | atlanta, ga', 'Company': 'Gresham, Smith and Partners.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b526695'), 'Title': 'associate research scientist', 'Company': 'R&D Partners', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b526696'), 'Title': 'entry-level electrical engineer', 'Company': 'Burns & McDonnell', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526697'), 'Title': 'staff software engineer', 'Company': 'General Electric', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526698'), 'Title': 'principal engineer', 'Company': 'Cotiviti', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b526699'), 'Title': 'devops engineer - elsys', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b52669a'), 'Title': 'senior analyst, payments study - gc insights, new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52669b'), 'Title': 'senior analyst - multi-client benchmarks, gc insights - new ventures', 'Company': 'McKinsey & Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52669c'), 'Title': 'bi - analytics - cloud platform operations analyst', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52669d'), 'Title': 'sr quantitative finance analyst/c++ developer', 'Company': 'Bank of America', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b52669e'), 'Title': 'business analytics consultant sr', 'Company': 'PNC Financial Services Group', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Consultant'}
# {'_id': ObjectId('5c04558297a998779b52669f'), 'Title': 'various professional, technical, administrative and scientific positions supporting a public health client', 'Company': 'Alaka`ina Foundation Family of Companies', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558297a998779b5266a0'), 'Title': 'senior engineer ii, packaging research', 'Company': 'The Coca-Cola Company', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558297a998779b5266a1'), 'Title': 'pediatrics â\x80\x93 dir. pediatric clinical and translational research', 'Company': 'Emory University', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558297a998779b5266a2'), 'Title': 'avionics system designer - elsys', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b5266a3'), 'Title': 'business development manager (southeast region)', 'Company': 'Catapult Sports', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b5266a4'), 'Title': 'senior research analyst and team lead - hr insights - bersin', 'Company': 'Deloitte', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558297a998779b5266a5'), 'Title': 'landscape architect (graduate)', 'Company': 'Jacobs', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b5266a6'), 'Title': 'implementation engineer (machine learning/data analytics)', 'Company': 'eHire, LLC', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558297a998779b5266a7'), 'Title': 'senior sales account executive', 'Company': 'Clear Story Data', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558297a998779b5266a8'), 'Title': 'post-doctoral fellowship training program in cancer epidemiology, prevention and survivorship', 'Company': 'AMERICAN CANCER SOCIETY', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558297a998779b5266a9'), 'Title': 'senior software researcher - cipher', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558297a998779b5266aa'), 'Title': 'configuration management/quality assurance manager -atas', 'Company': 'Georgia Tech Research Institute', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558297a998779b5266ab'), 'Title': 'practice technology regional bim manager (east region)', 'Company': 'HKS, Inc.', 'City': 'Atlanta', 'State': 'GA', 'Latitude': 33.7627, 'Longitude': -84.4231, 'Designation': 'Data Manager'}
# ...
# {'_id': ObjectId('5c04558497a998779b5280cf'), 'Title': 'senior clinical research associate', 'Company': 'Pharmacyclics, an Abbvie Company', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Research Analyst/Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280d0'), 'Title': 'senior software engineer', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280d1'), 'Title': 'paranoids sr software dev engineer', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558497a998779b5280d2'), 'Title': 'principal software engineer - telemetry', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280d3'), 'Title': 'senior software engineer- backend', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280d4'), 'Title': 'sr. front end developer - media brands and products', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558497a998779b5280d5'), 'Title': 'senior front end engineer', 'Company': 'Petuum, Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280d6'), 'Title': 'sr software dev engineer', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558497a998779b5280d7'), 'Title': 'principal software dev engineer', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558497a998779b5280d8'), 'Title': 'staff salesforce/java engineer', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280d9'), 'Title': 'sr front end engineer - oath monitoring team', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280da'), 'Title': 'principal technical program manager', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558497a998779b5280db'), 'Title': 'senior software engineer - back end', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280dc'), 'Title': 'senior designer, user experience', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558497a998779b5280dd'), 'Title': 'director of it, infrastructure, security & architecture', 'Company': 'Pharmacyclics, an Abbvie Company', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Director'}
# {'_id': ObjectId('5c04558497a998779b5280de'), 'Title': 'principal full stack javascript developer (front end)', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Developer'}
# {'_id': ObjectId('5c04558497a998779b5280df'), 'Title': 'senior platform software engineer - fixed networks gainspeed', 'Company': 'NOKIA', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b5280e0'), 'Title': 'senior designer, user experience - mobile', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558497a998779b5280e1'), 'Title': 'senior manager, sales operations', 'Company': 'Pharmacyclics, an Abbvie Company', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558497a998779b5280e2'), 'Title': 'senior/staff full stack engineer - advertising technologies', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Technician'}
# {'_id': ObjectId('5c04558497a998779b5280e3'), 'Title': 'senior manager, cost accounting', 'Company': 'Pharmacyclics, an Abbvie Company', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558497a998779b5280e4'), 'Title': 'security scientist', 'Company': 'Baidu USA', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280e5'), 'Title': 'sr data scientist', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280e6'), 'Title': 'applied scientist', 'Company': 'Lab126', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280e7'), 'Title': 'research scientist - idl (robotics)', 'Company': 'Baidu USA', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280e8'), 'Title': 'data scientist - ai-driven enterprise saas', 'Company': 'Clari', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280e9'), 'Title': 'data scientist- growth analytics', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ea'), 'Title': 'senior data scientist', 'Company': 'Castlight Health', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280eb'), 'Title': 'data scientist', 'Company': 'Proofpoint', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ec'), 'Title': 'head of data science, google cloud revenue acceleration', 'Company': 'Google', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ed'), 'Title': 'lead data scientist - machine learning', 'Company': 'TARGET', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ee'), 'Title': 'staff data scientist - tech ca (tech12458)', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ef'), 'Title': 'machine learning scientist', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f0'), 'Title': 'data scientist, path forward returnship', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f1'), 'Title': 'data scientist', 'Company': 'Linc Global, Inc.', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f2'), 'Title': 'data scientist - alexa language technologies', 'Company': 'Lab126', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f3'), 'Title': 'data scientist', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f4'), 'Title': 'data scientist', 'Company': 'Bosch Group', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f5'), 'Title': 'data scientist, cloud revenue acceleration, google cloud', 'Company': 'Google', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f6'), 'Title': 'data & applied scientist', 'Company': 'Microsoft', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f7'), 'Title': 'data scientist - alexa language technologies', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280f8'), 'Title': 'data scientist / data analyst', 'Company': 'Arosys', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558497a998779b5280f9'), 'Title': 'data scientist, customer interests & personalization', 'Company': 'Lab126', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280fa'), 'Title': 'data scientist, customer interests & personalization', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280fb'), 'Title': 'principal data scientist', 'Company': 'Microsoft', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280fc'), 'Title': 'data scientist, engineering support analytics, google cloud', 'Company': 'Google', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280fd'), 'Title': 'applied scientist', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280fe'), 'Title': 'staff data scientist', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b5280ff'), 'Title': 'staff data scientist, search/online grocery', 'Company': 'Walmart eCommerce', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528100'), 'Title': 'machine learning specialist, trust and safety', 'Company': 'Google', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Machine Learning Engineer'}
# {'_id': ObjectId('5c04558497a998779b528101'), 'Title': 'research scientist', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528102'), 'Title': 'applied machine learning scientist', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528103'), 'Title': 'scientist', 'Company': 'Microsoft', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528104'), 'Title': 'systems software performance data scientist sunnyvale/china', 'Company': 'Alibaba', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528105'), 'Title': 'applied scientist - alexa engine', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528106'), 'Title': 'lead data scientist - nlp', 'Company': 'TARGET', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528107'), 'Title': 'image processing deep learning research scientist', 'Company': 'Whiterabbit.ai', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528108'), 'Title': 'machine learning scientist, amazon alexa', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528109'), 'Title': 'global mobility specialist, immigration', 'Company': 'Google', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Other'}
# {'_id': ObjectId('5c04558497a998779b52810a'), 'Title': 'data engineer', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Engineer'}
# {'_id': ObjectId('5c04558497a998779b52810b'), 'Title': 'manager, machine learning', 'Company': 'Amazon.com', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Manager'}
# {'_id': ObjectId('5c04558497a998779b52810c'), 'Title': 'lead data scientist - haskell', 'Company': 'TARGET', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b52810d'), 'Title': 'senior data scientist (gec11902)', 'Company': 'Walmart', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b52810e'), 'Title': 'data developer / machine learning analyst', 'Company': 'NetApp', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Analyst'}
# {'_id': ObjectId('5c04558497a998779b52810f'), 'Title': 'scientist i', 'Company': 'Pharmacyclics, an Abbvie Company', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528110'), 'Title': 'intern scientist', 'Company': 'Oath Inc', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528111'), 'Title': 'senior data & applied scientist', 'Company': 'Microsoft', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
# {'_id': ObjectId('5c04558497a998779b528112'), 'Title': 'principal data scientist, deep learning', 'Company': 'Comcast', 'City': 'Sunnyvale', 'State': 'CA', 'Latitude': 37.3846, 'Longitude': -122.0261, 'Designation': 'Data Scientist'}
