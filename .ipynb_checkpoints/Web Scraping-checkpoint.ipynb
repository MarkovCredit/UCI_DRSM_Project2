# %%
from splinter import Browser
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import numpy as np
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.jobs_db
db.jobs_glassdoor.drop()
jobs_glassdoor_mongo = db.jobs_glassdoor

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
job_dict = {}

# %%
job_categories = ["Data Analyst", "Data Scientist"]
region = "United States"
posted_time = "7"
for job_category in job_categories:
    
    glassdoor_url = 'https://www.glassdoor.com/Job/jobs.htm?sc.keyword=' + job_category + \
    "&locT=N&locId=1&locKeyword=" + region + "&jobType=all&fromAge=" + posted_time + \
    "&minSalary=0&includeNoSalaryJobs=true&radius=-1&cityId=-1&minRating=0.0&industryId=-1" +\
    "&companyId=-1&applicationType=0&employerSizes=0&remoteWorkType=0"

    browser.visit(glassdoor_url)
    job_counter = 1
    for x in range(1, 20):
        print("Page no.:", x, "--------")
        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')

        job_section = soup.find('ul', class_='jlGrid')
        job_list = job_section.find_all('li', class_='jl')

        for job in job_list:
            # Job Title
            job_title = job.find('div', class_='jobTitle').a.text            
            # Company Name
            company_text = job.find('div', class_='empLoc').text.split("–")
            compay_name = company_text[0][1:][:-1] # formatting to remove the spaces in beginning and end
            # City and State
            location = job.find('div', class_='empLoc').span.text.split(", ")          
            # Salary information - Min, Max and Avg
            try:
                salary_text = job.find('span', class_="green").text.replace("(Glassdoor Est.)", "").replace("(Employer Est.)", "")
                sal_range = salary_text[1:].split("-")
                min_sal = int(sal_range[0].lstrip("$").rstrip("k"))
                max_sal = int(sal_range[1].lstrip("$").rstrip("k"))
                avg_sal = (max_sal+min_sal)/2   
            except AttributeError:
                min_sal = None
                max_sal = None
                avg_sal = None                
                
            print('job no.:', job_counter, '-------------')
            job_counter +=1

            job_dict = {"Title": job_title,
                        "Company": company_name,
                        "City": location[0],
                        "State": location[-1],
                        "Designation": job_category,
                        "Min Salary": min_sal,
                        "Max Salary": max_sal,
                        "Avg Salary", avg_sal,
                        "Source": "Glassdoor"
                        }
            jobs_glassdoor_mongo.insert_one(job_dict)

        try:
            browser.click_link_by_partial_text('Next')
             #If a pop-up window opens, close    
        except:
            browser.find_by_css('.xBtn').click()
        
        sleep(np.random.choice(range(4,7)))
    
    sleep(10)

# %%
browser.quit()

# %%
jobs_glassdoor_listing = db.jobs_glassdoor.find()
for listing in jobs_glassdoor_listing:
    print(listing)
# Out:
# {'_id': ObjectId('5c06046f0ea05e5c540c71cb'), 'Title': 'Data Analyst', 'Company': ' GameChanger ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71cc'), 'Title': 'Data Analyst', 'Company': ' T. Rowe Price ', 'City': 'Baltimore', 'State': 'MD', 'Designation': 'Data Analyst', 'Salary': ' $69k-$90k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71cd'), 'Title': 'Data Analyst', 'Company': ' SMC 3 ', 'City': 'Peachtree City', 'State': 'GA', 'Designation': 'Data Analyst', 'Salary': ' $53k-$72k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71ce'), 'Title': 'Data Analyst', 'Company': ' Trividia Health ', 'City': 'Fort Lauderdale', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': ' $57k-$78k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71cf'), 'Title': 'Data Analyst', 'Company': ' Walmart eCommerce ', 'City': 'Sunnyvale', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $91k-$123k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d0'), 'Title': 'APCD Data Analyst', 'Company': ' Freedman Healthcare ', 'City': 'Cranston', 'State': 'RI', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d1'), 'Title': 'Business Data Analyst', 'Company': ' GPM, Corp ', 'City': 'Asheville', 'State': 'NC', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d2'), 'Title': 'Data Analyst', 'Company': ' nference ', 'City': 'Cambridge', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d3'), 'Title': 'Data Analyst, Media Measurement', 'Company': ' MarketSearch ', 'City': 'New York', 'State': 'NY', 'Designation': 'Data Analyst', 'Salary': ' $60k-$80k(Employer Est.)', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d4'), 'Title': 'Data Analyst', 'Company': ' Northwestern Mutual ', 'City': 'Milwaukee', 'State': 'WI', 'Designation': 'Data Analyst', 'Salary': ' $61k-$80k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d5'), 'Title': 'Business Data Analyst', 'Company': ' Advance Financial ', 'City': 'Nashville', 'State': 'TN', 'Designation': 'Data Analyst', 'Salary': ' $45k-$65k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d6'), 'Title': 'Data Analyst', 'Company': ' Brightree ', 'City': 'Lawrenceville', 'State': 'GA', 'Designation': 'Data Analyst', 'Salary': ' $54k-$73k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d7'), 'Title': 'Business Intelligence Data Analyst', 'Company': ' Healthline Media ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $93k-$127k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d8'), 'Title': 'Data Integration Analyst', 'Company': ' EAB ', 'City': 'Richmond', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $47k-$73k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71d9'), 'Title': 'Junior Data Analyst', 'Company': ' IronEdge Group ', 'City': 'Houston', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71da'), 'Title': 'Data Analyst SmartHealth', 'Company': ' Ascension ', 'City': 'Austin', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': ' $55k-$74k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71db'), 'Title': 'Data Analyst', 'Company': ' VanderHouwen ', 'City': 'Beaverton', 'State': 'OR', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71dc'), 'Title': 'Data Analyst', 'Company': ' Smith Hanley Associates ', 'City': 'Jupiter', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71dd'), 'Title': 'Data Analyst, Search', 'Company': ' ezCater ', 'City': 'Boston', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $58k-$78k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71de'), 'Title': 'Data Analyst', 'Company': ' Pactera ', 'City': 'Redmond', 'State': 'WA', 'Designation': 'Data Analyst', 'Salary': ' $45k-$61k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71df'), 'Title': 'Data Analyst', 'Company': ' Urban Airship ', 'City': 'Portland', 'State': 'OR', 'Designation': 'Data Analyst', 'Salary': ' $62k-$85k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e0'), 'Title': 'Data Analyst', 'Company': ' Hopper ', 'City': 'Cambridge', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e1'), 'Title': 'Data Analyst', 'Company': ' Facing History and Ourselves, Inc ', 'City': 'Brookline', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $51k-$70k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e2'), 'Title': 'Data Analyst', 'Company': ' First Republic Bank ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $72k-$95k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e3'), 'Title': 'Analyst, Data Analytics', 'Company': ' CMI Media LLC ', 'City': 'New York', 'State': 'NY', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e4'), 'Title': 'Data Analyst', 'Company': ' NCSA - Next College Student Athlete ', 'City': 'Chicago', 'State': 'IL', 'Designation': 'Data Analyst', 'Salary': ' $53k-$72k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e5'), 'Title': 'Data Analyst', 'Company': ' Fareportal Inc. ', 'City': 'New York', 'State': 'NY', 'Designation': 'Data Analyst', 'Salary': ' $58k-$80k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e6'), 'Title': 'Provider Network Data Analyst', 'Company': ' Affinity Health Plan ', 'City': 'Bronx', 'State': 'NY', 'Designation': 'Data Analyst', 'Salary': ' $58k-$79k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e7'), 'Title': 'Data/ Strategic Analyst', 'Company': ' Convergent ', 'City': 'Houston', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06046f0ea05e5c540c71e8'), 'Title': 'Data Support & Solutions Analyst', 'Company': ' Remedy Partners ', 'City': 'Norwalk', 'State': 'CT', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71e9'), 'Title': 'Data Analyst', 'Company': ' T. Rowe Price ', 'City': 'Baltimore', 'State': 'MD', 'Designation': 'Data Analyst', 'Salary': ' $69k-$90k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ea'), 'Title': 'Data Analyst', 'Company': ' GameChanger ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71eb'), 'Title': 'Data Analyst, Business Intelligence', 'Company': ' AllianceBernstein ', 'City': 'Nashville', 'State': 'TN', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ec'), 'Title': 'Data Analyst', 'Company': ' Dimension Data ', 'City': 'Centreville', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $50k-$70k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ed'), 'Title': 'Data and Reporting Analyst', 'Company': ' Fisher Investments ', 'City': 'Plano', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': ' $51k-$76k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ee'), 'Title': 'IT Product Data Analyst/Sr', 'Company': ' Steelcase ', 'City': 'Grand Rapids', 'State': 'MI', 'Designation': 'Data Analyst', 'Salary': ' $74k-$93k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ef'), 'Title': 'Business Intelligence Data Analyst', 'Company': ' Tax Defense Network ', 'City': 'Jacksonville', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': ' $42k-$56k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f0'), 'Title': 'Data Analyst', 'Company': ' Powerley ', 'City': 'Royal Oak', 'State': 'MI', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f1'), 'Title': 'Data Analyst', 'Company': ' PayPal ', 'City': 'San Jose', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $81k-$111k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f2'), 'Title': 'Data Analyst', 'Company': ' Mindlance ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $67k-$94k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f3'), 'Title': 'Fraud Data Analyst', 'Company': ' Vivid Seats ', 'City': 'Chicago', 'State': 'IL', 'Designation': 'Data Analyst', 'Salary': ' $51k-$69k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f4'), 'Title': 'Data Analyst', 'Company': ' Mastech ', 'City': 'Tampa', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f5'), 'Title': 'Data and Reporting Analyst', 'Company': ' FIS ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f6'), 'Title': 'Data Analyst', 'Company': ' Fairview Health Services ', 'City': 'Minneapolis', 'State': 'MN', 'Designation': 'Data Analyst', 'Salary': ' $53k-$71k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f7'), 'Title': 'Data Analyst', 'Company': ' AgCountry Farm Credit Services ', 'City': 'Fargo', 'State': 'ND', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f8'), 'Title': 'Data Analyst', 'Company': ' WordStream ', 'City': 'Boston', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $46k-$63k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71f9'), 'Title': 'Data Analyst', 'Company': ' HealthEquity Inc. ', 'City': 'Draper', 'State': 'UT', 'Designation': 'Data Analyst', 'Salary': ' $52k-$71k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71fa'), 'Title': 'Data Analyst', 'Company': ' Everlane ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $66k-$91k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71fb'), 'Title': 'Data Analyst', 'Company': ' Politico ', 'City': 'Arlington', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $61k-$82k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71fc'), 'Title': 'Data Analyst', 'Company': ' Gecko Robotics, Inc. ', 'City': 'Pittsburgh', 'State': 'PA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71fd'), 'Title': 'Data Analyst', 'Company': ' Dining Alliance ', 'City': 'New London', 'State': 'CT', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71fe'), 'Title': 'Data Analyst', 'Company': ' Uber ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $90k-$123k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c71ff'), 'Title': 'Data Analyst', 'Company': ' Banner Health ', 'City': 'Phoenix', 'State': 'AZ', 'Designation': 'Data Analyst', 'Salary': ' $63k-$85k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7200'), 'Title': 'Data Analyst', 'Company': ' Aquent ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7201'), 'Title': 'Data Analyst', 'Company': ' Earnin ', 'City': 'Palo Alto', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7202'), 'Title': 'Sr Data and Reporting Analyst', 'Company': ' Fhlb Des Moines ', 'City': 'Des Moines', 'State': 'IA', 'Designation': 'Data Analyst', 'Salary': ' $63k-$92k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7203'), 'Title': 'Client Data Analyst', 'Company': ' Optima Tax Relief ', 'City': 'Santa Ana', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $48k-$64k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7204'), 'Title': 'Data Analyst', 'Company': ' Vitamin T ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7205'), 'Title': 'Data Analyst', 'Company': ' Isys Technologies ', 'City': 'Silver Spring', 'State': 'MD', 'Designation': 'Data Analyst', 'Salary': ' $68k-$91k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7206'), 'Title': 'Senior Big Data Analyst', 'Company': ' Affinity Solutions ', 'City': 'San Jose', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $123k-$160k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7207'), 'Title': 'Senior Data Integration Analyst; Enrollment Services', 'Company': ' EAB ', 'City': 'Richmond', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $52k-$81k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604770ea05e5c540c7208'), 'Title': 'Analyst, Customer Data', 'Company': ' Electric Power Research Institute, Inc. ', 'City': 'Charlotte', 'State': 'NC', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604780ea05e5c540c7209'), 'Title': 'Data Analyst', 'Company': ' T. Rowe Price ', 'City': 'Baltimore', 'State': 'MD', 'Designation': 'Data Analyst', 'Salary': ' $69k-$90k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720a'), 'Title': 'Data Analyst', 'Company': ' GameChanger ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720b'), 'Title': 'Data Analyst, Business Intelligence', 'Company': ' AllianceBernstein ', 'City': 'Nashville', 'State': 'TN', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720c'), 'Title': 'Data Analyst', 'Company': ' Dimension Data ', 'City': 'Centreville', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $50k-$70k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720d'), 'Title': 'Data and Reporting Analyst', 'Company': ' Fisher Investments ', 'City': 'Plano', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': ' $51k-$76k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720e'), 'Title': 'IT Product Data Analyst/Sr', 'Company': ' Steelcase ', 'City': 'Grand Rapids', 'State': 'MI', 'Designation': 'Data Analyst', 'Salary': ' $74k-$93k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c720f'), 'Title': 'Business Intelligence Data Analyst', 'Company': ' Tax Defense Network ', 'City': 'Jacksonville', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': ' $42k-$56k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7210'), 'Title': 'Data Analyst', 'Company': ' Powerley ', 'City': 'Royal Oak', 'State': 'MI', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7211'), 'Title': 'Data Analyst', 'Company': ' PayPal ', 'City': 'San Jose', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $81k-$111k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7212'), 'Title': 'Data Analyst', 'Company': ' Mindlance ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $67k-$94k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7213'), 'Title': 'Fraud Data Analyst', 'Company': ' Vivid Seats ', 'City': 'Chicago', 'State': 'IL', 'Designation': 'Data Analyst', 'Salary': ' $51k-$69k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7214'), 'Title': 'Data Analyst', 'Company': ' Mastech ', 'City': 'Tampa', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7215'), 'Title': 'Data and Reporting Analyst', 'Company': ' FIS ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7216'), 'Title': 'Data Analyst', 'Company': ' Fairview Health Services ', 'City': 'Minneapolis', 'State': 'MN', 'Designation': 'Data Analyst', 'Salary': ' $53k-$71k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7217'), 'Title': 'Data Analyst', 'Company': ' AgCountry Farm Credit Services ', 'City': 'Fargo', 'State': 'ND', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7218'), 'Title': 'Data Analyst', 'Company': ' WordStream ', 'City': 'Boston', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $46k-$63k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7219'), 'Title': 'Data Analyst', 'Company': ' HealthEquity Inc. ', 'City': 'Draper', 'State': 'UT', 'Designation': 'Data Analyst', 'Salary': ' $52k-$71k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721a'), 'Title': 'Data Analyst', 'Company': ' Everlane ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $66k-$91k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721b'), 'Title': 'Data Analyst', 'Company': ' Politico ', 'City': 'Arlington', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $61k-$82k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721c'), 'Title': 'Data Analyst', 'Company': ' Gecko Robotics, Inc. ', 'City': 'Pittsburgh', 'State': 'PA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721d'), 'Title': 'Data Analyst', 'Company': ' Dining Alliance ', 'City': 'New London', 'State': 'CT', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721e'), 'Title': 'Data Analyst', 'Company': ' Uber ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $90k-$123k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c721f'), 'Title': 'Data Analyst', 'Company': ' Banner Health ', 'City': 'Phoenix', 'State': 'AZ', 'Designation': 'Data Analyst', 'Salary': ' $63k-$85k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7220'), 'Title': 'Data Analyst', 'Company': ' Aquent ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7221'), 'Title': 'Data Analyst', 'Company': ' Earnin ', 'City': 'Palo Alto', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7222'), 'Title': 'Sr Data and Reporting Analyst', 'Company': ' Fhlb Des Moines ', 'City': 'Des Moines', 'State': 'IA', 'Designation': 'Data Analyst', 'Salary': ' $63k-$92k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7223'), 'Title': 'Client Data Analyst', 'Company': ' Optima Tax Relief ', 'City': 'Santa Ana', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $48k-$64k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7224'), 'Title': 'Data Analyst', 'Company': ' Vitamin T ', 'City': 'Menlo Park', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7225'), 'Title': 'Data Analyst', 'Company': ' Isys Technologies ', 'City': 'Silver Spring', 'State': 'MD', 'Designation': 'Data Analyst', 'Salary': ' $68k-$91k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7226'), 'Title': 'Senior Big Data Analyst', 'Company': ' Affinity Solutions ', 'City': 'San Jose', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $123k-$160k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7227'), 'Title': 'Senior Data Integration Analyst; Enrollment Services', 'Company': ' EAB ', 'City': 'Richmond', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $52k-$81k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c0604790ea05e5c540c7228'), 'Title': 'Analyst, Customer Data', 'Company': ' Electric Power Research Institute, Inc. ', 'City': 'Charlotte', 'State': 'NC', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c7229'), 'Title': 'Data Analyst', 'Company': ' Walmart eCommerce ', 'City': 'Sunnyvale', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $91k-$123k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722a'), 'Title': 'Data Analyst', 'Company': ' Urban Airship ', 'City': 'Portland', 'State': 'OR', 'Designation': 'Data Analyst', 'Salary': ' $62k-$85k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722b'), 'Title': 'Business Data Analyst I - Clearview Analyst I', 'Company': ' Dover Corporation ', 'City': 'Richardson', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': ' $57k-$88k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722c'), 'Title': 'Data Analyst', 'Company': ' Progressive Insurance ', 'City': 'Mayfield Heights', 'State': 'OH', 'Designation': 'Data Analyst', 'Salary': ' $66k-$89k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722d'), 'Title': 'Data Analyst', 'Company': ' Transunion ', 'City': 'Roswell', 'State': 'GA', 'Designation': 'Data Analyst', 'Salary': ' $45k-$62k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722e'), 'Title': 'Data Analyst', 'Company': ' Electronic Arts ', 'City': 'Orlando', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': ' $55k-$73k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c722f'), 'Title': 'Data Analyst - Custom Analytics', 'Company': ' comScore ', 'City': 'Portland', 'State': 'OR', 'Designation': 'Data Analyst', 'Salary': ' $58k-$77k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c7230'), 'Title': 'Business / Data Analyst, Officer', 'Company': ' State Street Corporation ', 'City': 'Quincy', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $58k-$86k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c7231'), 'Title': 'Data Analyst', 'Company': ' Varite USA ', 'City': 'Carlsbad', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047d0ea05e5c540c7232'), 'Title': 'Data Analyst', 'Company': ' Palmer Group ', 'City': 'Des Moines', 'State': 'IA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7233'), 'Title': 'Data Analyst', 'Company': ' Lutron ', 'City': 'Lehigh Valley', 'State': 'PA', 'Designation': 'Data Analyst', 'Salary': ' $51k-$69k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7234'), 'Title': 'Data Analyst', 'Company': ' General Dynamics ', 'City': 'Little Rock', 'State': 'AR', 'Designation': 'Data Analyst', 'Salary': ' $50k-$65k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7235'), 'Title': 'Data Analyst', 'Company': ' TBC ', 'City': 'Palm Beach Gardens', 'State': 'FL', 'Designation': 'Data Analyst', 'Salary': ' $45k-$58k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7236'), 'Title': 'Data Analyst', 'Company': ' City of New York ', 'City': 'New York', 'State': 'NY', 'Designation': 'Data Analyst', 'Salary': ' $64k-$91k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7237'), 'Title': 'Data Analyst', 'Company': ' Boston Consulting Group ', 'City': 'Boston', 'State': 'MA', 'Designation': 'Data Analyst', 'Salary': ' $64k-$85k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7238'), 'Title': 'Data Analyst', 'Company': ' Teachstone Training ', 'City': 'Charlottesville', 'State': 'VA', 'Designation': 'Data Analyst', 'Salary': ' $48k-$63k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7239'), 'Title': 'Data Analyst', 'Company': ' Envoy ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723a'), 'Title': 'Data Analyst', 'Company': ' Zolon Tech ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $78k-$110k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723b'), 'Title': 'Data Analyst', 'Company': ' Booz Allen Hamilton Inc. ', 'City': 'Omaha', 'State': 'NE', 'Designation': 'Data Analyst', 'Salary': ' $61k-$78k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723c'), 'Title': 'Data Analyst', 'Company': ' Better Hire ', 'City': 'Birmingham', 'State': 'AL', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723d'), 'Title': 'HEDIS/Quality Improvement Data Analyst', 'Company': ' Blue Cross Blue Shield of Arizona Advantage ', 'City': 'Phoenix', 'State': 'AZ', 'Designation': 'Data Analyst', 'Salary': ' $67k-$89k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723e'), 'Title': 'Data Analyst & Pricing Specialist Internship', 'Company': ' Deutsche Post DHL ', 'City': 'Newark', 'State': 'NJ', 'Designation': 'Data Analyst', 'Salary': ' $42k-$59k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c723f'), 'Title': 'Data Analyst', 'Company': ' Highmark Health ', 'City': 'Pittsburgh', 'State': 'PA', 'Designation': 'Data Analyst', 'Salary': ' $56k-$74k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7240'), 'Title': 'Data Analyst', 'Company': ' ABAL Technologies ', 'City': 'Hamilton', 'State': 'NJ', 'Designation': 'Data Analyst', 'Salary': ' $61k-$82k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7241'), 'Title': 'Data Analyst', 'Company': ' MarshBerry ', 'City': 'Woodmere', 'State': 'OH', 'Designation': 'Data Analyst', 'Salary': ' $48k-$66k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7242'), 'Title': 'Data Analyst', 'Company': ' Atrilogy ', 'City': 'Phoenix', 'State': 'AZ', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7243'), 'Title': 'Data Analyst', 'Company': ' Harvest ', 'City': 'San Francisco', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7244'), 'Title': 'Data Management Analyst 3', 'Company': ' Northrop Grumman ', 'City': 'Redondo Beach', 'State': 'CA', 'Designation': 'Data Analyst', 'Salary': ' $58k-$89k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7245'), 'Title': 'Senior Data Analyst', 'Company': ' Hero Digital ', 'City': 'Philadelphia', 'State': 'PA', 'Designation': 'Data Analyst', 'Salary': ' $80k-$107k', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7246'), 'Title': 'Population Health Data Analyst - Danbury/NYC', 'Company': ' Arcadia.io ', 'City': 'United States', 'State': 'United States', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7247'), 'Title': 'Data Conversion Analyst I', 'Company': ' MatrixCare ', 'City': 'Bloomington', 'State': 'MN', 'Designation': 'Data Analyst', 'Salary': '', 'Source': 'Glassdoor'}
# {'_id': ObjectId('5c06047e0ea05e5c540c7248'), 'Title': 'Senior Quantitative Risk Analyst - Data Solutions', 'Company': ' USAA ', 'City': 'San Antonio', 'State': 'TX', 'Designation': 'Data Analyst', 'Salary': ' $87k-$113k', 'Source': 'Glassdoor'}
